# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Exploration

# %% [markdown]
#  ### 1.1 naming the columns.

# %%
df = pd.read_csv('adult.csv')
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 
              'relationship','race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 
              'native-country', 'salary']
df.head(20)
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# ...

# %% [markdown]
#  ### 1.2 check missing values and data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### 1.3 Since our target variable is salary, we look at its distribution with the value_counts() function and visualize it with the seaborn library.

# %%
plt.figure(figsize=(8,6))
sns.countplot(df['salary'])
print('Salary Distribution:')
df['salary'].value_counts()
# Out:
# Salary Distribution:
#  <=50K    24720
#  >50K      7841
# Name: salary, dtype: int64

# %% [markdown]
# ### 1.4.Let's look at the age characteristic of those whose salary is less than 50K and higher.

# %%
print(" Age characteristics of those whose salary is less than 50K:")
print(df[df['salary'] == ' <=50K'].age.describe())
print('')
print("Age characteristics of those whose salary is bigger than 50K:")
print(df[df['salary'] == ' >50K'].age.describe())
# Out:
#  Age characteristics of those whose salary is less than 50K:
# count    24720.000000
# mean        36.783738
# std         14.020088
# min         17.000000
# 25%         25.000000
# 50%         34.000000
# 75%         46.000000
# max         90.000000
# Name: age, dtype: float64
#
# Age characteristics of those whose salary is bigger than 50K:
# count    7841.000000
# mean       44.249841
# std        10.519028
# min        19.000000
# 25%        36.000000
# 50%        44.000000
# 75%        51.000000
# max        90.000000
# Name: age, dtype: float64

# %% [markdown]
# ### 1.5 education status

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['education'], order = df['education'].value_counts().index)
plt.xticks(rotation=70)
df['education'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2bf712899d6f> in <module>
# ----> 1 plt.figure(figsize=(12,8))
#       2 sns.countplot(df['education'], order = df['education'].value_counts().index)
#       3 plt.xticks(rotation=70)
#       4 df['education'].value_counts()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### 1.6 Education-Age

# %%
df.groupby('education')['age'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cf0f88f1e812> in <module>
# ----> 1 df.groupby('education')['age'].describe()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 1.7 Education- Hours per week - Salary

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="education", y="hours-per-week", data=df, hue="salary", palette='inferno')
plt.xticks(rotation=70)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-54626684256f> in <module>
# ----> 1 plt.figure(figsize=(12,8))
#       2 sns.barplot(x="education", y="hours-per-week", data=df, hue="salary", palette='inferno')
#       3 plt.xticks(rotation=70)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### 1.8 Education- Hours per week - Sex

# %%
plt.figure(figsize=(12,8))
sns.pointplot(x="education", y="hours-per-week", hue='sex', palette="dark", linestyles=["-", "--"], data=df)
plt.xticks(rotation=70)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b67c54fa860b> in <module>
# ----> 1 plt.figure(figsize=(12,8))
#       2 sns.pointplot(x="education", y="hours-per-week", hue='sex', palette="dark", linestyles=["-", "--"], data=df)
#       3 plt.xticks(rotation=70)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### 1.9 Finally, we combine the salary and gender groupings we did above, and review the weekly average working hours of people accordingly.
