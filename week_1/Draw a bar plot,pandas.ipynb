# %%
from matplotlib import pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('gapminder_total_fertility.csv', index_col=0)
df
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
df = df[['1800', '1900', '2000']]
df
# Out:
#                        1800  1900  2000
# Total fertility rate
# Abkhazia                NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.73
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                4.60  4.60  2.38
# Algeria                6.99  6.99  2.51
# ...                     ...   ...   ...
# Yugoslavia              NaN   NaN   NaN
# Zambia                 6.71  6.71  6.07
# Zimbabwe               6.75  6.75  4.07
# Åland                   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN
#
# [260 rows x 3 columns]

# %%
df = df.loc[['Germany', 'Austria', 'Canada']]
df
# Out:
#                       1800  1900  2000
# Total fertility rate
# Germany               5.40  4.93  1.35
# Austria               5.10  4.33  1.37
# Canada                5.72  4.04  1.51

# %%
df.plot.bar()
plt.savefig('bars.png')

# %%
df.plot.bar(figsize=(5,7))

# %%
df = pd.read_csv('gapminder_total_fertility.csv', index_col=0)
df = df.loc[['Germany', 'Austria', 'Canada']]
df.plot.bar(y='1950', width=0.7, color='orange')

# %%
df.transpose()
df
# Out:
#                       1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Germany               5.40  5.40  5.39  5.39  5.38  5.38  5.37  5.37  5.36
# Austria               5.10  5.10  5.10  5.10  5.10  5.10  5.10  5.10  5.10
# Canada                5.72  5.72  5.72  5.72  5.72  5.72  5.72  5.72  5.72
#
#                       1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate        ...
# Germany               5.36  ...  1.36  1.36  1.37  1.38  1.39  1.40  1.41
# Austria               5.10  ...  1.41  1.38  1.41  1.39  1.44  1.44  1.46
# Canada                5.72  ...  1.61  1.66  1.68  1.67  1.63  1.61  1.66
#
#                       2013  2014  2015
# Total fertility rate
# Germany               1.42  1.43  1.44
# Austria               1.47  1.48  1.50
# Canada                1.67  1.68  1.68
#
# [3 rows x 216 columns]

# %%
df = df.loc[['Germany', 'Austria', 'Canada']]
df = df[['1800', '1900', '2000']]
df.plot.bar()
