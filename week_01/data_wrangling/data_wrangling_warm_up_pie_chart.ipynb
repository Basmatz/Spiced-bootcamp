# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style= 'white')

# %% [markdown]
# ## What data scientist spend the most time doing

# %% [markdown]
# Create a pie chart* of what you think a typical day of a sata scientist looks like by giving sizes to the following labels:
# - 'Data wrangling & mining', color: 'deeppink'
# - 'Collecting data sets', color: 'lightseagreen'
# - 'Training & running ML models', color: 'gold'
# - 'Communicating with stakeholders', color: 'yellowgreen'

# %% [markdown]
# https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html

# %%
plt.figure(figsize=(10, 10))

#Anastasia
ax1=plt.subplot(4,3, 1)

ax1.set_title("Anastasia", size=20)
tasks = ["Data wrangling and mining", 'Collecting data sets', 'Training and running ML models', 'Communicating with stakeholders']
sizes = [0.2, 0.1,0.6, 0.1] 
colors = ['deeppink', 'lightseagreen', 'gold', 'yellowgreen']
plt.pie(sizes, colors=colors)

# Max 
ax2=plt.subplot(4,3, 2)
ax2.set_title("Max", size=20)

tasks = 'Data wrangling & mining', 'Collecting data sets', 'Training & running ML models', 'Communicating with stakeholders'
sizes = [40,15,25,15]
colors = ['deeppink',  'lightseagreen',  'gold', 'yellowgreen']
plt.pie(sizes,  colors = colors)

## Lara
ax3=plt.subplot(4,3, 3)
ax3.set_title("Lara", size=20)
tasks = ['Data wrangling & mining', 'Collecting data sets', 'Training & running ML models', 'Communicating with stakeholders']
sizes = [50, 20, 7, 23]
colors = ['deeppink', 'lightseagreen', 'gold', 'yellowgreen']
plt.pie(sizes,  colors = colors)

#Kriszta
ax4=plt.subplot(4,3, 4)
ax4.set_title("Kriszta", size=20)
tasks = ['Data wrangling & mining','Collecting data sets','Training & running ML models','Communicating with stakeholders','continually learning and updating skills']
sizes = [30,35,15,15,5]
colors = ['deeppink', 'lightseagreen','gold', 'yellowgreen','forestgreen']
plt.pie(sizes,  colors = colors)

#Esra
ax5=plt.subplot(4,3, 5)
ax5.set_title("Esra", size=20)
tasks = 'Data wrangling & mining', 'Collecting data sets', 'Training & running ML models', 'Communicating with stakeholders'
sizes = [25, 30, 17, 28]
colors = ['deeppink', 'lightseagreen', 'gold', 'yellowgreen']
plt.pie(sizes, colors = colors)

#Rafael
ax6=plt.subplot(4,3, 6)
ax6.set_title("Rafael", size=20)
tasks = ['Data wrangling & mining','Collecting data sets','Training & running ML models','Communicating with stakeholders']
sizes = [40,10,15,35]
colors = ['deeppink', 'lightseagreen','gold', 'yellowgreen']
plt.pie(sizes, colors = colors)

#Carina
ax7=plt.subplot(4,3, 7)
ax7.set_title("Carina", size=20)
tasks = ['Data wrangling & mining', 'Collecting data sets', 'Training & running ML models', 'Communicating with stakeholders']
sizes = [60, 20, 10, 10]
colors = ('deeppink', 'lightseagreen', 'gold', 'yellowgreen')
plt.pie(sizes, colors=colors)

#Felix
ax8=plt.subplot(4,3, 8)
ax8.set_title("Felix", size=20)
tasks = 'data wrangling & mining', 'Collecting data sets', 'Training & running ML models', 'Communicating with stakeholders'
sizes = [30, 15, 5, 50]
colors = 'deeppink', 'lightseagreen', 'gold', 'yellowgreen'
plt.pie(sizes, colors=colors)

#Sara
ax9=plt.subplot(4,3, 9)
ax9.set_title("Sara", size=20)
tasks = ['Data Wrangling and mining', 'Collecting data sets', 'Training and running ML models', 'Communicating with stakeholders']
sizes = [60,20,5,15]
colors = ['deeppink', 'lightseagreen', 'gold', 'yellowgreen']
plt.pie(sizes, colors=colors)

#Braulio
ax10=plt.subplot(4,3, 10)
ax10.set_title("Braulio", size=20)
tasks = 'Data wrangling & mining', 'Collecting data sets', 'Training & running ML models', 'Communicating with stakeholders'
sizes = [40, 25, 20, 15]
colors = ['deeppink', 'lightseagreen', 'gold', 'yellowgreen']
plt.pie(sizes, colors = colors)

#Denny
ax11=plt.subplot(4,3, 11)
ax11.set_title("Denny", size=20)
tasks = ['Data wrangling & mining','Collecting data sets', 'Training & running ML models', 'Communicating with stakeholders'] 
sizes = [50, 20, 7, 23]
colors = ['deeppink', 'lightseagreen', 'gold', 'yellowgreen']
plt.pie(sizes, colors = colors)


plt.tight_layout()
plt.figlegend(title="Legend",labels=tasks, loc = 'lower right')
plt.show()

# %% [markdown]
# * Pie charts are a heavily discussed plot in the DataViz community. If you ever want to make another pie chart follow these guidelines: https://blog.datawrapper.de/pie-charts/ but in general try to avoid them unless they are part of class.
