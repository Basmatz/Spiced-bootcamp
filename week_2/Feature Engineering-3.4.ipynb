# %%
pwd
# Out:
# 'C:\\Users\\Kriszta\\Desktop\\datas'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('train.csv', index_col=0)
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
sns.heatmap(df.isna())

# %%
#  impute missing values in the age column

age_mean= df['Age'].mean()
age_mean
# Out:
# 29.69911764705882

# %%
df['Age'].fillna(age_mean, inplace = True)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
#                    Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1            22.000000      1      0         A/5 21171   7.2500   NaN        S
# 2            38.000000      1      0          PC 17599  71.2833   C85        C
# 3            26.000000      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4            35.000000      1      0            113803  53.1000  C123        S
# 5            35.000000      0      0            373450   8.0500   NaN        S
# ...                ...    ...    ...               ...      ...   ...      ...
# 887          27.000000      0      0            211536  13.0000   NaN        S
# 888          19.000000      0      0            112053  30.0000   B42        S
# 889          29.699118      1      2        W./C. 6607  23.4500   NaN        S
# 890          26.000000      0      0            111369  30.0000  C148        C
# 891          32.000000      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
# apply one-hot encoding

# %%
df_hot=pd.get_dummies(df['Sex'])
df_hot.head(10)
# Out:
#              female  male
# PassengerId
# 1                 0     1
# 2                 1     0
# 3                 1     0
# 4                 1     0
# 5                 0     1
# 6                 0     1
# 7                 0     1
# 8                 0     1
# 9                 1     0
# 10                1     0

# %%
pd.concat([df,df_hot], axis=1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name        Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.000000
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000
# 3                                       Heikkinen, Miss. Laina  26.000000
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000
# 5                                     Allen, Mr. William Henry  35.000000
# ...                                                        ...        ...
# 887                                      Montvila, Rev. Juozas  27.000000
# 888                               Graham, Miss. Margaret Edith  19.000000
# 889                   Johnston, Miss. Catherine Helen "Carrie"  29.699118
# 890                                      Behr, Mr. Karl Howell  26.000000
# 891                                        Dooley, Mr. Patrick  32.000000
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  female  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S       0
# 2                1      0          PC 17599  71.2833   C85        C       1
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S       1
# 4                1      0            113803  53.1000  C123        S       1
# 5                0      0            373450   8.0500   NaN        S       0
# ...            ...    ...               ...      ...   ...      ...     ...
# 887              0      0            211536  13.0000   NaN        S       0
# 888              0      0            112053  30.0000   B42        S       1
# 889              1      2        W./C. 6607  23.4500   NaN        S       1
# 890              0      0            111369  30.0000  C148        C       0
# 891              0      0            370376   7.7500   NaN        Q       0
#
#              male
# PassengerId
# 1               1
# 2               0
# 3               0
# 4               0
# 5               1
# ...           ...
# 887             1
# 888             0
# 889             0
# 890             1
# 891             1
#
# [891 rows x 12 columns]

# %%
# bin the age column

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age_bins']= pd.cut(df['Age'], bins=[0,18,30,60,80], labels=['under 18', 'between 18 and 30', 'between 30 and 60','over 60'])

# %%
df['Age_bins']
# Out:
# PassengerId
# 1      between 18 and 30
# 2      between 30 and 60
# 3      between 18 and 30
# 4      between 30 and 60
# 5      between 30 and 60
#              ...
# 887    between 18 and 30
# 888    between 18 and 30
# 889    between 18 and 30
# 890    between 18 and 30
# 891    between 30 and 60
# Name: Age_bins, Length: 891, dtype: category
# Categories (4, object): [under 18 < between 18 and 30 < between 30 and 60 < over 60]
