# %% [markdown]
# # Step 1: Import Pandas and read files

# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/monikaju'

# %%
cd Desktop
# Out:
# /Users/monikaju/Desktop

# %%
pwd
# Out:
# '/Users/monikaju/Desktop'

# %%
fert = pd.read_csv('gapminder_total_fertility.csv')

# %%
fert
# Out:
#       Total fertility rate  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0                 Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2    Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                  Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                  Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ..                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 255             Yugoslavia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256                 Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# 257               Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# 258                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259                  Åland   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %% [markdown]
# # Step 2: Read the excel file

# %%
life = pd.read_excel ('gapminder_lifeexpectancy.xlsx')

# %%
life
# Out:
#            Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0                 Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1              Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2    Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                  Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                  Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ..                     ...    ...    ...    ...    ...    ...    ...    ...
# 255             Yugoslavia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 256                 Zambia  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# 257               Zimbabwe  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# 258                  Åland    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 259            South Sudan  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %% [markdown]
# # Step 3: Shapes

# %%
print (life.shape)
# Out:
# (260, 218)

# %%
print (fert.shape)
# Out:
# (260, 217)

# %% [markdown]
# **This table has the columns as strings

# %%
fert.columns
# Out:
# Index(['Total fertility rate', '1800', '1801', '1802', '1803', '1804', '1805',
#        '1806', '1807', '1808',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=217)

# %% [markdown]
# **This table has the columns as numbers

# %%
life.columns
# Out:
# Index(['Life expectancy',              1800,              1801,
#                     1802,              1803,              1804,
#                     1805,              1806,              1807,
#                     1808,
#        ...
#                     2007,              2008,              2009,
#                     2010,              2011,              2012,
#                     2013,              2014,              2015,
#                     2016],
#       dtype='object', length=218)

# %%
# Change 'total fertility' and 'life expentacy' to index

# %%
fert2 = fert.set_index('Total fertility rate')

# %%
fert2.head(3)
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan             7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan             7.0  ...   6.7  6.46   6.2  5.93  5.66   5.4  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015
# Total fertility rate
# Abkhazia                NaN   NaN   NaN
# Afghanistan             4.9  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
#
# [3 rows x 216 columns]

# %%
life2 = life.set_index('Life expectancy')

# %%
life2.head(3)
# Out:
#                         1800  1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.2  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015   2016
# Life expectancy
# Abkhazia                NaN   NaN   NaN    NaN
# Afghanistan            54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN    NaN
#
# [3 rows x 217 columns]

# %% [markdown]
# # Step 4: Change string columns to integer numbers

# %%
ncol = [int (x) for x in fert2.columns]

# %%
fert2.set_axis(axis=1,labels=ncol,inplace= True)

# %%
fert2
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
fert2.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %% [markdown]
# # Step 5: Create a hierarchical index

# %%
sfert2 = fert2.stack()

# %%
slife2 = life2.stack()

# %%
sfert2
# Out:
# Total fertility rate
# Afghanistan           1800    7.00
#                       1801    7.00
#                       1802    7.00
#                       1803    7.00
#                       1804    7.00
#                               ...
# Zimbabwe              2011    3.64
#                       2012    3.56
#                       2013    3.49
#                       2014    3.41
#                       2015    3.35
# Length: 43412, dtype: float64

# %%
slife2
# Out:
# Life expectancy
# Afghanistan      1800    28.21
#                  1801    28.20
#                  1802    28.19
#                  1803    28.18
#                  1804    28.17
#                          ...
# South Sudan      2012    56.00
#                  2013    56.00
#                  2014    56.10
#                  2015    56.10
#                  2016    56.10
# Length: 43857, dtype: float64

# %%
d = {'fertility': sfert2, 'lifeexp': slife2}

# %%
df2 = pd.DataFrame(data=d)

# %%
df2
# Out:
#                   fertility  lifeexp
# Afghanistan 1800        7.0    28.21
#             1801        7.0    28.20
#             1802        7.0    28.19
#             1803        7.0    28.18
#             1804        7.0    28.17
# ...                     ...      ...
# Åland       2002        NaN    81.80
#             2003        NaN    80.63
#             2004        NaN    79.88
#             2005        NaN    80.00
#             2006        NaN    80.10
#
# [44007 rows x 2 columns]

# %% [markdown]
# # Step 6:  Repeat the above stages for the 'gapminder' population file

# %%
pwd
# Out:
# '/Users/monikaju/Desktop'

# %%
popu = pd.read_excel('gapminder_population.xlsx')

# %%
popu
# Out:
#                                  Total population       1800       1810  \
# 0                                        Abkhazia        NaN        NaN
# 1                                     Afghanistan  3280000.0  3280000.0
# 2                           Akrotiri and Dhekelia        NaN        NaN
# 3                                         Albania   410445.0   423591.0
# 4                                         Algeria  2503218.0  2595056.0
# ..                                            ...        ...        ...
# 270                             Northern Marianas        NaN        NaN
# 271  South Georgia and the South Sandwich Islands        NaN        NaN
# 272                     US Minor Outlying Islands        NaN        NaN
# 273                                Virgin Islands        NaN        NaN
# 274                                     West Bank        NaN        NaN
#
#           1820       1830       1840       1850       1860       1870  \
# ...

# %%
pop.shape
# Out:
# (275, 82)

# %%
popu.columns
# Out:
# Index(['Total population',               1800,               1810,
#                      1820,               1830,               1840,
#                      1850,               1860,               1870,
#                      1880,               1890,               1900,
#                      1910,               1920,               1930,
#                      1940,               1950,               1951,
#                      1952,               1953,               1954,
#                      1955,               1956,               1957,
#                      1958,               1959,               1960,
#                      1961,               1962,               1963,
#                      1964,               1965,               1966,
#                      1967,               1968,               1969,
#                      1970,               1971,               1972,
#                      1973,               1974,               1975,
# ...

# %%
popu2 = popu.set_index('Total population')

# %%
popu2
# Out:
#                                                    1800       1810       1820  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
# ...

# %%
spopu = popu2.stack()

# %%
spopu
# Out:
# Total population
# Afghanistan                1800    3280000.0
#                            1810    3280000.0
#                            1820    3323519.0
#                            1830    3448982.0
#                            1840    3625022.0
#                                      ...
# Sint Maarten (Dutch part)  2011      33979.0
#                            2012      35134.0
#                            2013      36442.0
#                            2014      37696.0
#                            2015      38745.0
# Length: 20176, dtype: float64

# %%
# Merging the columns

# %%
d = {'fertility': sfert2, 'lifeexp': slife2, 'population': spopu}

# %%
df2 = pd.DataFrame(data=d)

# %%
df2
# Out:
#                   fertility  lifeexp  population
# Afghanistan 1800        7.0    28.21   3280000.0
#             1801        7.0    28.20         NaN
#             1802        7.0    28.19         NaN
#             1803        7.0    28.18         NaN
#             1804        7.0    28.17         NaN
# ...                     ...      ...         ...
# Åland       2006        NaN    80.10     26923.0
#             2007        NaN      NaN     26923.0
#             2008        NaN      NaN     26923.0
#             2009        NaN      NaN     26923.0
#             2010        NaN      NaN     26923.0
#
# [47688 rows x 3 columns]

# %% [markdown]
# # Step 7: Creating the right table

# %%
df3 = df2.stack()

# %%
df3
# Out:
# Afghanistan  1800  fertility           7.00
#                    lifeexp            28.21
#                    population    3280000.00
#              1801  fertility           7.00
#                    lifeexp            28.20
#                                     ...
# Åland        2006  population      26923.00
#              2007  population      26923.00
#              2008  population      26923.00
#              2009  population      26923.00
#              2010  population      26923.00
# Length: 107445, dtype: float64

# %%
df4 = df3.unstack((0,2))

# %%
df4
# Out:
#      Afghanistan                     Akrotiri and Dhekelia   Albania          \
#        fertility lifeexp  population            population fertility lifeexp
# 1800        7.00   28.21   3280000.0                   NaN      4.60    35.4
# 1801        7.00   28.20         NaN                   NaN      4.60    35.4
# 1802        7.00   28.19         NaN                   NaN      4.60    35.4
# 1803        7.00   28.18         NaN                   NaN      4.60    35.4
# 1804        7.00   28.17         NaN                   NaN      4.60    35.4
# ...          ...     ...         ...                   ...       ...     ...
# 2012        5.14   54.40  29726803.0                   NaN      1.76    77.5
# 2013        4.90   54.80  30682500.0                   NaN      1.77    77.7
# 2014        4.68   54.90  31627506.0                   NaN      1.78    77.9
# 2015        4.47   53.80  32526562.0                   NaN      1.78    78.0
# ...

# %%
df4.head(10)
# Out:
#      Afghanistan                    Akrotiri and Dhekelia   Albania          \
#        fertility lifeexp population            population fertility lifeexp
# 1800         7.0   28.21  3280000.0                   NaN       4.6    35.4
# 1801         7.0   28.20        NaN                   NaN       4.6    35.4
# 1802         7.0   28.19        NaN                   NaN       4.6    35.4
# 1803         7.0   28.18        NaN                   NaN       4.6    35.4
# 1804         7.0   28.17        NaN                   NaN       4.6    35.4
# 1805         7.0   28.16        NaN                   NaN       4.6    35.4
# 1806         7.0   28.15        NaN                   NaN       4.6    35.4
# 1807         7.0   28.14        NaN                   NaN       4.6    35.4
# 1808         7.0   28.13        NaN                   NaN       4.6    35.4
# 1809         7.0   28.12        NaN                   NaN       4.6    35.4
#
# ...

# %% [markdown]
# # STEP 8: select specif columns and plot them

# %%
import pylab as plt
df4[['Germany', 'France', 'Sweden']].plot()

# %%
df5 = df3.unstack(2)

# %%
df5
# Out:
#                   fertility  lifeexp  population
# Afghanistan 1800        7.0    28.21   3280000.0
#             1801        7.0    28.20         NaN
#             1802        7.0    28.19         NaN
#             1803        7.0    28.18         NaN
#             1804        7.0    28.17         NaN
# ...                     ...      ...         ...
# Åland       2006        NaN    80.10     26923.0
#             2007        NaN      NaN     26923.0
#             2008        NaN      NaN     26923.0
#             2009        NaN      NaN     26923.0
#             2010        NaN      NaN     26923.0
#
# [47688 rows x 3 columns]

# %%
df5.plot.scatter('fertility','lifeexp', s=0.1)

# %%
df6 = df3.unstack(1)
df6 = df6[1950]
df6 = df6.unstack(1)
df6.plot.scatter('fertility', 'lifeexp', s=0.1)

# %%
cmap = plt.get_cmap('tab20', lut = len(df6)).colors
df6.plot.scatter('fertility', 'lifeexp', s=0.1, c=cmap)

# %%
df6.plot.scatter('fertility', 'lifeexp', s=df6['population'])

# %%
df6
# Out:
#                        fertility  lifeexp    population
# Afghanistan                 7.67    26.85  1.550424e-08
# Akrotiri and Dhekelia        NaN      NaN  2.132200e-11
# Albania                     5.80    54.48  2.526342e-09
# Algeria                     7.65    42.77  1.774449e-08
# American Samoa               NaN      NaN  3.787400e-11
# ...                          ...      ...           ...
# Yemen                       7.27    23.51  8.804640e-09
# Yugoslavia                   NaN      NaN  3.257105e-08
# Zambia                      6.71    42.85  4.633900e-09
# Zimbabwe                    6.75    48.46  5.493708e-09
# Åland                        NaN      NaN  4.329800e-11
#
# [256 rows x 3 columns]

# %%
# reduce the scale of population 
df6["population"] = 0.00001 * df6["population"]

# %%
df6
# Out:
#                        fertility  lifeexp  population
# Afghanistan                 7.67    26.85    77.52118
# Akrotiri and Dhekelia        NaN      NaN     0.10661
# Albania                     5.80    54.48    12.63171
# Algeria                     7.65    42.77    88.72247
# American Samoa               NaN      NaN     0.18937
# ...                          ...      ...         ...
# Yemen                       7.27    23.51    44.02320
# Yugoslavia                   NaN      NaN   162.85527
# Zambia                      6.71    42.85    23.16950
# Zimbabwe                    6.75    48.46    27.46854
# Åland                        NaN      NaN     0.21649
#
# [256 rows x 3 columns]

# %% [markdown]
# # STEP 9: Color each country differently

# %%
cmap = plt.get_cmap('tab10', lut = len(df6)).colors
df6.plot.scatter('fertility', 'lifeexp',s=df6 ['population'], c=cmap)

# %% [markdown]
# #loop to generate the 55 images

# %% [markdown]
# # STEP 10: Scatter plots 1960-2015 / STEP 11: Adjusting population size

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# '/Users/monikaju/Desktop'

# %%
year_list = list(range(1960,2016))
df_in = df3.unstack(1)

def makeplot (df3, year):
    
    def_temp = df_in[year]
    def_temp = def_temp.unstack(1)
    
    x = def_temp['fertility']
    y = def_temp['lifeexp']
    sizes = def_temp['population']/10**5 # in 100k units (otherwise will overwhelm the scale)
    cmap = plt.get_cmap('Pastel2', lut = len(def_temp)).colors

    
    fig = plt.scatter(x, y,
                s = sizes,
                c = cmap,   
                alpha=0.3)
    plt.axis([1, 10, 20, 80])
    plt.xlabel('Fertility')
    plt.ylabel('Life Expectancy (Years)')
    plt.title(str(year))
    
    plt.savefig('scatter_' + str(year) + '.png', dpi = 150)
    plt.clf() 
    
    return

for date in year_list:
    makeplot(df3, date)

# %% [markdown]
# # STEP 12: Create the gif

# %%
import imageio

# %%
images = []

for i in range(1960, 2015):
    filename = 'scatter_{}.png'.format(i)
    images.append(imageio.imread(filename))

imageio.mimsave('output.gif', images, fps=20)
