# %%
import matplotlib.pyplot as plt

tasks = 'Data wrangling & mining', 'Collecting data sets', 'Training & running ML models', 'Communicating with stakeholders'
sizes = [25, 30, 17, 28]
colors = ['deeppink', 'lightseagreen', 'gold', 'yellowgreen']
plt.pie(sizes, labels = tasks, colors = colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x22ab8ca8a08>,
#   <matplotlib.patches.Wedge at 0x22ab8ca8dc8>,
#   <matplotlib.patches.Wedge at 0x22ab8cb33c8>,
#   <matplotlib.patches.Wedge at 0x22ab8cb3448>],
#  [Text(0.7778174593052024, 0.7778174593052024, 'Data wrangling & mining'),
#   Text(-0.8899187180267095, 0.6465637441936395, 'Collecting data sets'),
#   Text(-0.7274429854179931, -0.825122235166498, 'Training & running ML models'),
#   Text(0.7011664649040885, -0.8475645040313473, 'Communicating with stakeholders')])
