# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='white')

# %%
tasks = ['Data wrangling & mining','Collecting data sets','Training & running ML models','Communicating with stakeholders']
sizes = [40,10,15,35]
colors = ['deeppink', 'lightseagreen','gold', 'yellowgreen']
plt.pie(sizes, labels = tasks, colors = colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9e74512710>,
# ...
#  [Text(0.33991867422268784, 1.0461621742897658, 'Data wrangling & mining'),
#   Text(-1.0461621822461362, 0.3399186497354951, 'Collecting data sets'),
#   Text(-0.9801071438778459, -0.49938961394847997, 'Training & running ML models'),
#   Text(0.4993896139484799, -0.9801071438778459, 'Communicating with stakeholders')])
